# %% [markdown]
# # Load Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tia_posts.csv', parse_dates=['date_gmt'])
df.head()
# Out:
#        id            date_gmt  \
# 0  736193 2022-03-08 05:00:16
# 1  736448 2022-03-08 04:28:58
# 2  736439 2022-03-08 03:57:05
# 3  736427 2022-03-08 03:08:38
# 4  734160 2022-03-08 03:00:51
#
#                                                title  \
# 0  How India’s tech titans square up against Chin...
# 1        Una Brands to invest $100m into South Korea
# 2     Wavemaker Partners closes fourth fund at $136m
# 3  Temasek, Tencent back $200m round of Australia...
# 4  This deck helped an Islamic fintech firm raise...
#
#                                                 slug          type  \
# 0            indias-tech-titans-square-chinese-peers  visual-story
# 1  singapores-una-brands-commits-100m-acquiring-s...          post
# 2         wavemaker-partners-fourth-fund-136-million          post
# 3                      immutable-200-million-funding          post
# 4                                               iman  visual-story
#
#                                              content  \
# 0  Image credit: Timmy LoenHours before India’s i...
# 1  Una Brands, a Singapore-based ecommerce roll-u...
# 2  Southeast Asian VC firm Wavemaker Partners has...
# 3  Immutable, an Australia-based blockchain start...
# 4  ﻿ ABOUTImanis an Uzbekistan-based fintech firm...
#
#                                              excerpt  author_id  \
# 0  Legacy businesses still dominate Indian tech, ...     530158
# 1  Through a partnership with KlickBrands, Una Br...     270460
# 2  Wavemaker Partners has more than 10 exits so f...      86192
# 3  Immutable said its platform can process 9,000 ...      86192
# 4  Iman offers fintech services that follow the m...     470877
#
#            author_name  author_is_staff  ... comments_count  \
# 0         Tay Tian Wen             True  ...              0
# 1        Miguel Cordon             True  ...              0
# 2  Aditya Hadi Pratama             True  ...              0
# 3  Aditya Hadi Pratama             True  ...              0
# 4           Deepti Sri             True  ...              0
#
#                                           categories  \
# 0              ['Premium Content', 'Visual Stories']
# 1   ['Ecommerce', 'Investments', 'News', 'Startups']
# 2                               ['News', 'Startups']
# 3  ['Blockchain', 'Investments', 'News', 'Startups']
# 4                                 ['Visual Stories']
#
#                                                 tags is_sponsored  \
# 0  ['Asia', 'China', 'china vs tech giants', 'Chi...        False
# 1  ['Acquisition', 'Ecommerce', 'ecommerce rollup...        False
# 2  ['gavin lee', 'International Finance Corporati...        False
# 3  ['Alex Connolly', 'Animoca Brands', 'Australia...        False
# 4  ['buy now pay later', 'fintech', 'Iman', 'Isla...        False
#
#    sponsor_name show_ads  is_subscriber_exclusive  is_paywalled  \
# 0           NaN     True                     True          True
# 1           NaN     True                    False          True
# 2           NaN     True                    False          True
# 3           NaN     True                    False          True
# 4           NaN     True                    False          True
#
#    is_inappbrowser  read_time
# 0            False          4
# 1            False          1
# 2            False          2
# 3            False          2
# 4            False          1
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (900, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 21 columns):
# id                         900 non-null int64
# date_gmt                   900 non-null datetime64[ns]
# title                      900 non-null object
# slug                       900 non-null object
# type                       900 non-null object
# content                    900 non-null object
# excerpt                    900 non-null object
# author_id                  900 non-null int64
# author_name                900 non-null object
# author_is_staff            900 non-null bool
# editor                     843 non-null object
# comments_count             900 non-null int64
# categories                 900 non-null object
# tags                       900 non-null object
# is_sponsored               900 non-null bool
# sponsor_name               37 non-null object
# show_ads                   900 non-null bool
# is_subscriber_exclusive    900 non-null bool
# is_paywalled               900 non-null bool
# is_inappbrowser            900 non-null bool
# read_time                  900 non-null int64
# dtypes: bool(6), datetime64[ns](1), int64(4), object(10)
# memory usage: 110.9+ KB

# %%
df.describe()
# Out:
#                   id      author_id  comments_count   read_time
# count     900.000000     900.000000      900.000000  900.000000
# mean   725769.078889  415519.953333        0.100000    2.331111
# std     25701.592251  197432.883457        0.582465    1.990894
# min    485312.000000     217.000000        0.000000    1.000000
# 25%    727261.500000  242465.000000        0.000000    1.000000
# 50%    730267.000000  470877.000000        0.000000    2.000000
# 75%    733061.500000  580372.000000        0.000000    3.000000
# max    736448.000000  717239.000000       11.000000   16.000000

# %%
df.columns
# Out:
# Index(['id', 'date_gmt', 'title', 'slug', 'type', 'content', 'excerpt',
#        'author_id', 'author_name', 'author_is_staff', 'editor',
#        'comments_count', 'categories', 'tags', 'is_sponsored', 'sponsor_name',
#        'show_ads', 'is_subscriber_exclusive', 'is_paywalled',
#        'is_inappbrowser', 'read_time'],
#       dtype='object')

# %% [markdown]
# # Question

# %% [markdown]
# ## 1.
