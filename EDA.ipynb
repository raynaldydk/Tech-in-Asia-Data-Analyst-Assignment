# %% [markdown]
# # Load Dataset

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# %%
df = pd.read_csv('tia_posts.csv', parse_dates=['date_gmt'])
df.head()
# Out:
#        id            date_gmt  \
# 0  737074 2022-03-10 10:26:12
# 1  737077 2022-03-10 10:01:08
# 2  737066 2022-03-10 09:30:59
# 3  736884 2022-03-10 09:30:23
# 4  736984 2022-03-10 08:51:06
#
#                                                title  \
# 0  Krafton-backed 🇮🇳 game streaming firm raises $42m
# 1   Malaysian gov’t taps AWS to boost cloud adoption
# 2  🇮🇳 Roundup: PUBG developer bets on audio conte...
# 3  The first-hand accounts of SEA’s female entrep...
# 4  Tiger Global leads $20m series B extension of ...
#
#                                              content          author_name  \
# 0  India-based Loco, a streaming platform for vid...          Kul Bhushan
# 1  Amazon Web Services (AWS) and the Malaysian go...  Roehl Niño Bautista
# 2  Startups in India, including Loco and Kuku FM,...        Samreen Ahmad
# 3  Sign up for the Daily Newsletter, sent exclusi...        Winston Zhang
# 4  Cialfo, a Singapore-based edtech startup, has ...  Aditya Hadi Pratama
#
#                                   editor  comments_count  \
# 0  Samreen Ahmad and Lorenzo Kyle Subido               0
# 1     Deepti Sri and Lorenzo Kyle Subido               0
# 2     Deepti Sri and Lorenzo Kyle Subido               0
# 3                             Jaclyn Tiu               0
# 4           Miguel Cordon and Jaclyn Tiu               0
#
#                                           categories  show_ads  \
# 0  ['Blockchain', 'Gaming', 'Investments', 'News'...      True
# 1                          ['Consumer Tech', 'News']      True
# 2                ['Investments', 'News', 'Startups']      True
# 3                                    ['Newsletters']      True
# 4                ['Investments', 'News', 'Startups']      True
#
#    is_subscriber_exclusive  read_time
# 0                    False          2
# 1                    False          1
# 2                    False          1
# 3                    False          6
# 4                    False          3

# %%
df.shape
# Out:
# (900, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       900 non-null    int64
#  1   date_gmt                 900 non-null    datetime64[ns]
#  2   title                    900 non-null    object
#  3   content                  900 non-null    object
#  4   author_name              900 non-null    object
#  5   editor                   841 non-null    object
#  6   comments_count           900 non-null    int64
#  7   categories               900 non-null    object
#  8   show_ads                 900 non-null    bool
#  9   is_subscriber_exclusive  900 non-null    bool
#  10  read_time                900 non-null    int64
# dtypes: bool(2), datetime64[ns](1), int64(3), object(5)
# memory usage: 65.2+ KB

# %% [markdown]
# # EDA

# %% [markdown]
# ## Question 1: What categories are interesting to user?

# %%
Image(url= "img/avg_comment_by_cat.png")
# Out:
# <img src="img/avg_comment_by_cat.png"/>

# %% [markdown]
# - Size of Bubble: Average Comments
# - Color of Bubble: Average Read Time (Blue < Red)

# %% [markdown]
# ## Answer 1:
# - In posts that are not subscriber exclusive Tech in Asia Jobs and Recruitment have most average comments & least read time.
# - In posts that are subscriber exclusive Invesments and Startups have most average comments & least read time.
# - Fintech, Analysis & Blockchain have good average comments, but it also have a high read time.
# - We can improve Fintech, Analysis & Blockchain categories by make it more engaging to user.

# %% [markdown]
# ## Question 2: Are user get articles they want to read?

# %%
Image(url= "img/articles_distribution.png")
# Out:
# <img src="img/articles_distribution.png"/>

# %% [markdown]
# ## Answer 2:
# - For the most part user already get articles they want to see, except for TIA Jobs & Recruitment.
# - We can improve by adding more articles for those categories.

# %% [markdown]
# ## Question 3: What is the best time to post article?

# %%
Image(url= "img/avg_comment_day_hour.png")
# Out:
# <img src="img/avg_comment_day_hour.png"/>

# %% [markdown]
# ## Answer 3:
# - User comments more in the morning, except for some days.
# - In Monday, Friday there are more comments in the night than in morning.
# - Friday is make sense but Monday, why user comments more on Monday night?

# %% [markdown]
# ## Question 4: Articles posted at the correct day ?

# %%
Image(url= "img/total_posts_day.png")
# Out:
# <img src="img/total_posts_day.png"/>

# %% [markdown]
# ## Answer 4:
# - Looking at Average Comment by Day & Hour, we still need to get more articles at Saturday.
# - We need other metrics like Click Rate or How many times user shared the article, to confirm.
# - We can improve articles on Saturday and Sunday using automated bot to post articles.

# %% [markdown]
# ## Question 5: Who are the top 10 author by number of articles posted ?

# %%
Image(url= "img/top10_author.png")
# Out:
# <img src="img/top10_author.png"/>

# %% [markdown]
# ## Answer 5:
# - Those are the top 10 author by number of articles posted.
# - Since they are people that have the most impact to the TIA articles, I want to analyze if they are good writers and try to find what makes them good.

# %% [markdown]
# # Analyzing Top 10 Author

# %%
df_new = df.copy()
df_new = df_new[['author_name', 'content']]
df_new.shape
# Out:
# (900, 2)

# %%
df_new.head()
# Out:
#            author_name                                            content
# 0          Kul Bhushan  India-based Loco, a streaming platform for vid...
# 1  Roehl Niño Bautista  Amazon Web Services (AWS) and the Malaysian go...
# 2        Samreen Ahmad  Startups in India, including Loco and Kuku FM,...
# 3        Winston Zhang  Sign up for the Daily Newsletter, sent exclusi...
# 4  Aditya Hadi Pratama  Cialfo, a Singapore-based edtech startup, has ...

# %%
top10_author = df_new.author_name.value_counts()[:10].index
top10_author
# Out:
# Index(['Samreen Ahmad', 'Aditya Hadi Pratama', 'Deepti Sri',
#        'Roehl Niño Bautista', 'Miguel Cordon', 'Kul Bhushan', 'TIA Bot',
#        'Shravanth Vijayakumar', 'Daniel Rouquette', 'Stefanie Yeo'],
#       dtype='object')

# %%
df_new = df_new[df_new['author_name'].isin(top10_author)]
df_new.head()
# Out:
#            author_name                                            content
# 0          Kul Bhushan  India-based Loco, a streaming platform for vid...
# 1  Roehl Niño Bautista  Amazon Web Services (AWS) and the Malaysian go...
# 2        Samreen Ahmad  Startups in India, including Loco and Kuku FM,...
# 4  Aditya Hadi Pratama  Cialfo, a Singapore-based edtech startup, has ...
# 5  Aditya Hadi Pratama  Aria, an Indonesia-based agritech startup, has...

# %% [markdown]
# ## Corpus

# %%
data = df_new.groupby('author_name')['content'].apply(lambda x: ','.join(x.astype(str))).reset_index()
data
# Out:
#              author_name                                            content
# 0    Aditya Hadi Pratama  Cialfo, a Singapore-based edtech startup, has ...
# 1       Daniel Rouquette  This is the Daily News Roundup. Delivered ever...
# 2             Deepti Sri  Singapore-based insurtech firm Igloo has raise...
# 3            Kul Bhushan  India-based Loco, a streaming platform for vid...
# 4          Miguel Cordon  Singapore-based Silent Eight, a startup offeri...
# 5    Roehl Niño Bautista  Amazon Web Services (AWS) and the Malaysian go...
# 6          Samreen Ahmad  Startups in India, including Loco and Kuku FM,...
# 7  Shravanth Vijayakumar  Sign up for the Daily Newsletter, sent exclusi...
# 8           Stefanie Yeo  As part of Tech in Asia’s 2022 International W...
# 9                TIA Bot  Southeast Asia has seen its fair share of M&am...

# %%
data.content[0]
# Out:
# "Cialfo, a Singapore-based edtech startup, has raised another US$20 million in series B funding led by US-based investment firm Tiger Global after it raised US$40 million in January this year.\nIn total, the company has raised US$77 million in funding to date. VentureCap Insights pegged the firm’s valuation at around US$230 million.\n\n(From left) Cialfo founders Stanley Chia, Rohan Pasari, and William Hund / Photo credit: Cialfo\n\nFounded by Rohan Pasari, Stanley Chia, and William Hund in 2017, Cialfo is a software-as-a-service firm that simplifies the career exploration and college search process by connecting high schoolers, counselors, and colleges. It charges annual subscriptions for education institutions, while keeping the platform free for students.\nThe firm currently has 270,000 active students on its platform, with around 70% of them coming from India, Southeast Asia, and China. It also has more than 1,000 colleges in 50 countries using its platform.\nCialfo plans to use the fresh funding to develop its product, enhance its marketing initiatives, hire new employees, and explore strategic acquisition opportunities.\nInvestor interest\nWhen Pasari signed the term sheet for the initial US$40 million series B funding, which was led by Square Peg and Seek Investments, he said Tiger Global quickly approached him to join the round.\n“I said, the round is over. The round is also oversubscribed, as we initially only wanted to raise around US$20 million. I told them to enter the next round in the next six to 12 months,” Pasari told Tech in Asia.\nHowever, Tiger Global insisted on investing in the same round, so the co-founder accepted the request and signed another term sheet after a “quick” due diligence process from the VC firm.\nSee also: Series SEA: Who’s investing in the region’s education startups?\nWhile Cialfo isn’t profitable right now, Pasari said it has healthy gross margins and unit economics and that the company “can be profitable as soon as next year if we want.”\nIn 2022, the company plans to add more features, such as direct application capabilities in mobile devices, and career journey path that can help students in determining their future. It also wants to capitalize on its historical data on student acceptance at various universities and turn it into career suggestions for new users.\nCialfo currently has more than 200 employees – a third of them work in product development, another third in marketing, and the rest in customer support and operations. Of its headcount, Pasari said 51% are women.\nInspired by experience\nHaving been born and raised in Calcutta, Pasari said that he had no idea how to apply for universities in other countries when he was a student. Fortunately, two universities from Singapore – Nanyang Technological University (NTU) and the National University of Singapore – came to his high school. He ended up getting a scholarship from NTU and becoming an engineering major.\n“It’s a life changing impact for me, and that’s the main idea of Cialfo,” Pasari explained.\n\nCialfo co-founder Rohan Pasari / Photo credit: Cialfo\n\nAt NTU, he met Chia when they both took an entrepreneurship course. The two were part of different teams and ended up competing against each other, which Pasari said built their respect for one another.\n“We decided that if we wanted to build a company, we should team up,” he said.\nThe duo then built Cialfo and marketed the product to a large education company in Shanghai, where Hund was working as head of product. He asked to join the company instead, and two months later, he was already in Singapore as the firm’s chief product officer.\nAccording to Pasari, the biggest challenge for Cialfo right now is hiring the best talent and keeping the company focused.\n“We have an interest to move to other businesses, but not until we have more than 50% global market share in our current offering,” he shared.,Aria, an Indonesia-based agritech startup, has raised an undisclosed a ...

# %%
# Apply a first round of text cleaning techniques
import re
import string

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

round1 = lambda x: clean_text_round1(x)

# %%
data['content'] = data.content.apply(round1)
data
# Out:
#              author_name                                            content
# 0    Aditya Hadi Pratama  cialfo a singaporebased edtech startup has rai...
# 1       Daniel Rouquette  this is the daily news roundup delivered every...
# 2             Deepti Sri  singaporebased insurtech firm igloo has raised...
# 3            Kul Bhushan  indiabased loco a streaming platform for video...
# 4          Miguel Cordon  singaporebased silent eight a startup offering...
# 5    Roehl Niño Bautista  amazon web services aws and the malaysian gove...
# 6          Samreen Ahmad  startups in india including loco and kuku fm r...
# 7  Shravanth Vijayakumar  sign up for the daily newsletter sent exclusiv...
# 8           Stefanie Yeo  as part of tech in asia’s  international women...
# 9                TIA Bot  southeast asia has seen its fair share of mamp...

# %%
# Apply a second round of cleaning
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
# Let's take a look at the updated text
data['content'] = data.content.apply(round2)
data
# Out:
#              author_name                                            content
# 0    Aditya Hadi Pratama  cialfo a singaporebased edtech startup has rai...
# 1       Daniel Rouquette  this is the daily news roundup delivered every...
# 2             Deepti Sri  singaporebased insurtech firm igloo has raised...
# 3            Kul Bhushan  indiabased loco a streaming platform for video...
# 4          Miguel Cordon  singaporebased silent eight a startup offering...
# 5    Roehl Niño Bautista  amazon web services aws and the malaysian gove...
# 6          Samreen Ahmad  startups in india including loco and kuku fm r...
# 7  Shravanth Vijayakumar  sign up for the daily newsletter sent exclusiv...
# 8           Stefanie Yeo  as part of tech in asias  international womens...
# 9                TIA Bot  southeast asia has seen its fair share of mamp...

# %%
idx = ['aditya', 'daniel', 'deepti', 'kul', 'miguel', 'roehl', 'samreen', 'shravanth', 'stefanie', 'tia bot']
data.index = idx

# %%
data
# Out:
#                      author_name  \
# aditya       Aditya Hadi Pratama
# daniel          Daniel Rouquette
# deepti                Deepti Sri
# kul                  Kul Bhushan
# miguel             Miguel Cordon
# roehl        Roehl Niño Bautista
# samreen            Samreen Ahmad
# shravanth  Shravanth Vijayakumar
# stefanie            Stefanie Yeo
# tia bot                  TIA Bot
#
#                                                      content
# aditya     cialfo a singaporebased edtech startup has rai...
# daniel     this is the daily news roundup delivered every...
# deepti     singaporebased insurtech firm igloo has raised...
# kul        indiabased loco a streaming platform for video...
# miguel     singaporebased silent eight a startup offering...
# roehl      amazon web services aws and the malaysian gove...
# samreen    startups in india including loco and kuku fm r...
# shravanth  sign up for the daily newsletter sent exclusiv...
# stefanie   as part of tech in asias  international womens...
# tia bot    southeast asia has seen its fair share of mamp...

# %%
# Let's pickle it for later use
data.to_pickle("corpus.pkl")

# %% [markdown]
# ## Document-Term Matrix

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data.content)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = data.index
data_dtm
# Out:
# C:\Users\ASUS\miniconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#            aadit  aakash  aampt  aapl  aapsky  aarna  aaron  aatmanirbhar  \
# aditya         0       0      0     0       0      0      0             0
# daniel         0       0      0     0       0      0      0             0
# deepti         4       1      0     0       0      0      2             0
# kul            0       0      0     0       0      0      0             0
# miguel         0       1      0     0       0      1      0             0
# roehl          0       0      0     0       1      0      0             0
# samreen        0       0      1     0       0      0      0             1
# shravanth      1       0      0     1       0      0      0             0
# stefanie       0       0      0     0       0      0      0             0
# tia bot        0       0      0     0       0      0      0             0
#
#            aave  aavegotchi  ...  zuckerbergthese  zuddl  zuhaib  zuper  \
# aditya        0           0  ...                0      1       0      0
# daniel        0           0  ...                0      0       0      0
# deepti        0           0  ...                0      0       0      0
# kul           1           1  ...                0      0       0      0
# miguel        0           0  ...                0      0       0      0
# roehl         0           0  ...                0      0       0      0
# samreen       0           0  ...                0      0       1      1
# shravanth     0           0  ...                0      0       0      0
# stefanie      0           0  ...                1      0       0      0
# tia bot       0           0  ...                0      0       0      0
#
#            zurichbased  zwc  zymrat  zynga  zynn  zypp
# aditya               0    0       0      0     0     0
# daniel               0    0       0      0     0     0
# deepti               1    2       0      0     0     1
# kul                  0    0       0      0     0     0
# miguel               0    0       1      0     0     0
# roehl                0    0       0      0     0     0
# samreen              0    0       0      0     1     0
# shravanth            1    0       0      1     0     0
# stefanie             0    0       0      0     0     0
# tia bot              0    0       0      0     0     0
#
# [10 rows x 20976 columns]

# %%
# Let's pickle it for later use
import pickle

data_dtm.to_pickle("dtm.pkl")
pickle.dump(cv, open("cv.pkl", "wb"))

# %% [markdown]
# ## Most Common Words

# %%
# Read in the document-term matrix
data = pd.read_pickle('dtm.pkl')
data = data.transpose()
data.head()
# Out:
#         aditya  daniel  deepti  kul  miguel  roehl  samreen  shravanth  \
# aadit        0       0       4    0       0      0        0          1
# aakash       0       0       1    0       1      0        0          0
# aampt        0       0       0    0       0      0        1          0
# aapl         0       0       0    0       0      0        0          1
# aapsky       0       0       0    0       0      1        0          0
#
#         stefanie  tia bot
# aadit          0        0
# aakash         0        0
# aampt          0        0
# aapl           0        0
# aapsky         0        0

# %%
# Find the top 30 words by each author
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'aditya': [('million', 263),
#   ('company', 197),
#   ('raised', 135),
#   ('funding', 133),
#   ('round', 122),
#   ('firm', 122),
#   ('credit', 111),
#   ('startup', 107),
#   ('said', 103),
#   ('platform', 99),
#   ('ventures', 97),
#   ('year', 82),
#   ('series', 80),
#   ('capital', 76),
#   ('plans', 71),
#   ('new', 71),
#   ('photo', 70),
#   ('indonesia', 66),
#   ('tech', 66),
#   ('currently', 64),
#   ('led', 63),
#   ('use', 60),
#   ('fresh', 59),
#   ('investors', 57),
#   ('users', 57),
#   ('app', 56),
#   ('business', 49),
#   ('startups', 49),
#   ('investment', 49),
#   ('cofounder', 49)],
#  'daniel': [('tech', 78),
#   ('news', 60),
#   ('asia', 57),
#   ('startups', 51),
#   ('premium', 43),
#   ('day', 43),
#   ('biggest', 43),
#   ('february', 37),
#   ('global', 34),
#   ('access', 34),
#   ('firm', 30),
#   ('nfts', 26),
#   ('startup', 25),
#   ('southeast', 25),
#   ('workshop', 24),
#   ('crypto', 24),
#   ('funding', 23),
#   ('big', 23),
#   ('fintech', 21),
#   ('free', 21),
#   ('daily', 21),
#   ('new', 21),
#   ('break', 21),
#   ('stories', 21),
#   ('read', 21),
#   ('roundup', 21),
#   ('trends', 20),
#   ('digital', 20),
#   ('website', 20),
#   ('inbox', 20)],
#  'deepti': [('million', 206),
#   ('company', 170),
#   ('said', 126),
#   ('firm', 121),
#   ('tech', 118),
#   ('credit', 118),
#   ('capital', 116),
#   ('raised', 107),
#   ('asia', 105),
#   ('round', 103),
#   ('platform', 97),
#   ('new', 97),
#   ('investors', 89),
#   ('southeast', 80),
#   ('market', 80),
#   ('firms', 80),
#   ('delivery', 79),
#   ('billion', 78),
#   ('companies', 76),
#   ('india', 72),
#   ('ventures', 70),
#   ('global', 69),
#   ('startup', 69),
#   ('series', 68),
#   ('including', 68),
#   ('investment', 64),
#   ('led', 62),
#   ('services', 61),
#   ('startups', 61),
#   ('funding', 56)],
#  'kul': [('million', 193),
#   ('company', 132),
#   ('firm', 126),
#   ('startup', 99),
#   ('said', 98),
#   ('round', 95),
#   ('india', 91),
#   ('platform', 88),
#   ('credit', 85),
#   ('raised', 82),
#   ('capital', 81),
#   ('new', 70),
#   ('plans', 62),
#   ('investors', 61),
#   ('tech', 60),
#   ('billion', 60),
#   ('funding', 58),
#   ('startups', 57),
#   ('series', 52),
#   ('services', 51),
#   ('cofounder', 48),
#   ('fresh', 47),
#   ('photo', 46),
#   ('growth', 46),
#   ('asia', 45),
#   ('market', 44),
#   ('group', 44),
#   ('led', 44),
#   ('ventures', 43),
#   ('indian', 42)],
#  'miguel': [('million', 142),
#   ('said', 133),
#   ('company', 120),
#   ('tech', 71),
#   ('credit', 71),
#   ('new', 70),
#   ('platform', 67),
#   ('firm', 61),
#   ('year', 61),
#   ('round', 61),
#   ('capital', 55),
#   ('startup', 52),
#   ('india', 51),
#   ('startups', 49),
#   ('billion', 49),
#   ('ceo', 47),
#   ('companies', 47),
#   ('raised', 43),
#   ('singapore', 41),
#   ('services', 37),
#   ('photo', 37),
#   ('team', 37),
#   ('investors', 36),
#   ('ventures', 34),
#   ('help', 32),
#   ('funding', 32),
#   ('firms', 31),
#   ('digital', 31),
#   ('plans', 30),
#   ('global', 30)],
#  'roehl': [('million', 156),
#   ('credit', 85),
#   ('platform', 81),
#   ('firm', 81),
#   ('said', 77),
#   ('digital', 70),
#   ('round', 70),
#   ('company', 64),
#   ('india', 60),
#   ('raised', 57),
#   ('tech', 54),
#   ('billion', 50),
#   ('new', 50),
#   ('series', 50),
#   ('photo', 49),
#   ('ecommerce', 49),
#   ('firms', 47),
#   ('funding', 46),
#   ('ventures', 46),
#   ('asia', 45),
#   ('capital', 43),
#   ('services', 42),
#   ('southeast', 41),
#   ('bank', 41),
#   ('led', 41),
#   ('ceo', 40),
#   ('development', 39),
#   ('market', 39),
#   ('fund', 35),
#   ('food', 34)],
#  'samreen': [('million', 237),
#   ('india', 162),
#   ('company', 133),
#   ('tech', 118),
#   ('said', 108),
#   ('platform', 101),
#   ('credit', 98),
#   ('startup', 92),
#   ('asia', 80),
#   ('raised', 77),
#   ('fintech', 77),
#   ('billion', 74),
#   ('firm', 73),
#   ('round', 73),
#   ('funding', 71),
#   ('digital', 65),
#   ('capital', 65),
#   ('investors', 63),
#   ('global', 61),
#   ('fund', 60),
#   ('crypto', 59),
#   ('ecommerce', 58),
#   ('year', 56),
#   ('new', 55),
#   ('southeast', 55),
#   ('ceo', 53),
#   ('startups', 53),
#   ('users', 52),
#   ('market', 50),
#   ('investment', 49)],
#  'shravanth': [('million', 195),
#   ('tech', 159),
#   ('company', 134),
#   ('startups', 121),
#   ('startup', 108),
#   ('firm', 102),
#   ('round', 101),
#   ('capital', 98),
#   ('asia', 95),
#   ('funding', 87),
#   ('southeast', 81),
#   ('raised', 81),
#   ('billion', 81),
#   ('digital', 76),
#   ('new', 74),
#   ('series', 70),
#   ('platform', 68),
#   ('credit', 67),
#   ('year', 67),
#   ('newsletter', 64),
#   ('ecommerce', 64),
#   ('investors', 62),
#   ('premium', 61),
#   ('market', 61),
#   ('fintech', 58),
#   ('financial', 58),
#   ('sea', 57),
#   ('companies', 56),
#   ('group', 56),
#   ('led', 56)],
#  'stefanie': [('tech', 88),
#   ('startup', 79),
#   ('new', 66),
#   ('million', 62),
#   ('asia', 61),
#   ('firm', 58),
#   ('southeast', 54),
#   ('company', 48),
#   ('digital', 45),
#   ('startups', 44),
#   ('services', 40),
#   ('fraud', 37),
#   ('female', 36),
#   ('funding', 35),
#   ('platform', 35),
#   ('firms', 35),
#   ('raised', 35),
#   ('like', 34),
#   ('credit', 33),
#   ('asias', 30),
#   ('founders', 30),
#   ('year', 30),
#   ('businesses', 30),
#   ('customers', 29),
#   ('round', 29),
#   ('bank', 27),
#   ('people', 27),
#   ('series', 26),
#   ('indonesia', 26),
#   ('just', 25)],
#  'tia bot': [('data', 93),
#   ('startups', 71),
#   ('weve', 68),
#   ('companies', 58),
#   ('list', 57),
#   ('funding', 53),
#   ('investors', 53),
#   ('tech', 50),
#   ('firms', 47),
#   ('past', 43),
#   ('raised', 39),
#   ('years', 39),
#   ('lists', 35),
#   ('generated', 35),
#   ('head', 35),
#   ('constantly', 35),
#   ('updated', 35),
#   ('autogenerated', 35),
#   ('invested', 34),
#   ('asia', 33),
#   ('deals', 32),
#   ('money', 27),
#   ('theyve', 25),
#   ('herewhich', 25),
#   ('asias', 25),
#   ('read', 24),
#   ('southeast', 24),
#   ('content', 23),
#   ('researchtechinasiacom', 22),
#   ('impact', 22)]}

# %%
# Print the top 15 words by each author
for author, top_words in top_dict.items():
    print(author)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# aditya
# million, company, raised, funding, round, firm, credit, startup, said, platform, ventures, year, series, capital
# ---
# daniel
# tech, news, asia, startups, premium, day, biggest, february, global, access, firm, nfts, startup, southeast
# ---
# deepti
# million, company, said, firm, tech, credit, capital, raised, asia, round, platform, new, investors, southeast
# ---
# kul
# million, company, firm, startup, said, round, india, platform, credit, raised, capital, new, plans, investors
# ---
# miguel
# million, said, company, tech, credit, new, platform, firm, year, round, capital, startup, india, startups
# ---
# roehl
# million, credit, platform, firm, said, digital, round, company, india, raised, tech, billion, new, series
# ---
# samreen
# million, india, company, tech, said, platform, credit, startup, asia, raised, fintech, billion, firm, round
# ---
# shravanth
# million, tech, company, startups, startup, firm, round, capital, asia, funding, southeast, raised, billion, digital
# ---
# stefanie
# tech, startup, new, million, asia, firm, southeast, company, digital, startups, services, fraud, female, funding
# ---
# tia bot
# data, startups, weve, companies, list, funding, investors, tech, firms, past, raised, years, lists, generated
# ---

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each author
words = []
for author in data.columns:
    top = [word for (word, count) in top_dict[author]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['million',
#  'company',
#  'raised',
#  'funding',
#  'round',
#  'firm',
#  'credit',
#  'startup',
#  'said',
#  'platform',
#  'ventures',
#  'year',
#  'series',
#  'capital',
#  'plans',
#  'new',
#  'photo',
#  'indonesia',
#  'tech',
#  'currently',
#  'led',
#  'use',
#  'fresh',
#  'investors',
#  'users',
#  'app',
#  'business',
#  'startups',
#  'investment',
#  'cofounder',
#  'tech',
#  'news',
#  'asia',
#  'startups',
#  'premium',
#  'day',
#  'biggest',
#  'february',
#  'global',
#  'access',
#  'firm',
#  'nfts',
#  'startup',
#  'southeast',
#  'workshop',
#  'crypto',
#  'funding',
#  'big',
#  'fintech',
#  'free',
#  'daily',
#  'new',
#  'break',
#  'stories',
#  'read',
#  'roundup',
#  'trends',
#  'digital',
#  'website',
#  'inbox',
#  'million',
#  'company',
#  'said',
#  'firm',
#  'tech',
#  'credit',
#  'capital',
#  'raised',
#  'asia',
#  'round',
#  'platform',
#  'new',
#  'investors',
#  'southeast',
#  'market',
#  'firms',
#  'delivery',
#  'billion',
#  'companies',
#  'india',
#  'ventures',
#  'global',
#  'startup',
#  'series',
#  'including',
#  'investment',
#  'led',
#  'services',
#  'startups',
#  'funding',
#  'million',
#  'company',
#  'firm',
#  'startup',
#  'said',
#  'round',
#  'india',
#  'platform',
#  'credit',
#  'raised',
#  'capital',
#  'new',
#  'plans',
#  'investors',
#  'tech',
#  'billion',
#  'funding',
#  'startups',
#  'series',
#  'services',
#  'cofounder',
#  'fresh',
#  'photo',
#  'growth',
#  'asia',
#  'market',
#  'group',
#  'led',
#  'ventures',
#  'indian',
#  'million',
#  'said',
#  'company',
#  'tech',
#  'credit',
#  'new',
#  'platform',
#  'firm',
#  'year',
#  'round',
#  'capital',
#  'startup',
#  'india',
#  'startups',
#  'billion',
#  'ceo',
#  'companies',
#  'raised',
#  'singapore',
#  'services',
#  'photo',
#  'team',
#  'investors',
#  'ventures',
#  'help',
#  'funding',
#  'firms',
#  'digital',
#  'plans',
#  'global',
#  'million',
#  'credit',
#  'platform',
#  'firm',
#  'said',
#  'digital',
#  'round',
#  'company',
#  'india',
#  'raised',
#  'tech',
#  'billion',
#  'new',
#  'series',
#  'photo',
#  'ecommerce',
#  'firms',
#  'funding',
#  'ventures',
#  'asia',
#  'capital',
#  'services',
#  'southeast',
#  'bank',
#  'led',
#  'ceo',
#  'development',
#  'market',
#  'fund',
#  'food',
#  'million',
#  'india',
#  'company',
#  'tech',
#  'said',
#  'platform',
#  'credit',
#  'startup',
#  'asia',
#  'raised',
#  'fintech',
#  'billion',
#  'firm',
#  'round',
#  'funding',
#  'digital',
#  'capital',
#  'investors',
#  'global',
#  'fund',
#  'crypto',
#  'ecommerce',
#  'year',
#  'new',
#  'southeast',
#  'ceo',
#  'startups',
#  'users',
#  'market',
#  'investment',
#  'million',
#  'tech',
#  'company',
#  'startups',
#  'startup',
#  'firm',
#  'round',
#  'capital',
#  'asia',
#  'funding',
#  'southeast',
#  'raised',
#  'billion',
#  'digital',
#  'new',
#  'series',
#  'platform',
#  'credit',
#  'year',
#  'newsletter',
#  'ecommerce',
#  'investors',
#  'premium',
#  'market',
#  'fintech',
#  'financial',
#  'sea',
#  'companies',
#  'group',
#  'led',
#  'tech',
#  'startup',
#  'new',
#  'million',
#  'asia',
#  'firm',
#  'southeast',
#  'company',
#  'digital',
#  'startups',
#  'services',
#  'fraud',
#  'female',
#  'funding',
#  'platform',
#  'firms',
#  'raised',
#  'like',
#  'credit',
#  'asias',
#  'founders',
#  'year',
#  'businesses',
#  'customers',
#  'round',
#  'bank',
#  'people',
#  'series',
#  'indonesia',
#  'just',
#  'data',
#  'startups',
#  'weve',
#  'companies',
#  'list',
#  'funding',
#  'investors',
#  'tech',
#  'firms',
#  'past',
#  'raised',
#  'years',
#  'lists',
#  'generated',
#  'head',
#  'constantly',
#  'updated',
#  'autogenerated',
#  'invested',
#  'asia',
#  'deals',
#  'money',
#  'theyve',
#  'herewhich',
#  'asias',
#  'read',
#  'southeast',
#  'content',
#  'researchtechinasiacom',
#  'impact']

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('funding', 10),
#  ('tech', 10),
#  ('raised', 9),
#  ('firm', 9),
#  ('new', 9),
#  ('startups', 9),
#  ('million', 8),
#  ('company', 8),
#  ('round', 8),
#  ('credit', 8),
#  ('startup', 8),
#  ('platform', 8),
#  ('asia', 8),
#  ('capital', 7),
#  ('investors', 7),
#  ('southeast', 7),
#  ('said', 6),
#  ('series', 6),
#  ('digital', 6),
#  ('billion', 6),
#  ('ventures', 5),
#  ('year', 5),
#  ('led', 5),
#  ('market', 5),
#  ('firms', 5),
#  ('india', 5),
#  ('services', 5),
#  ('photo', 4),
#  ('global', 4),
#  ('companies', 4),
#  ('plans', 3),
#  ('investment', 3),
#  ('fintech', 3),
#  ('ceo', 3),
#  ('ecommerce', 3),
#  ('indonesia', 2),
#  ('fresh', 2),
#  ('users', 2),
#  ('cofounder', 2),
#  ('premium', 2),
#  ('crypto', 2),
#  ('read', 2),
#  ('group', 2),
#  ('bank', 2),
#  ('fund', 2),
#  ('asias', 2),
#  ('currently', 1),
#  ('use', 1),
#  ('app', 1),
#  ('business', 1),
#  ('news', 1),
#  ('day', 1),
#  ('biggest', 1),
#  ('february', 1),
#  ('access', 1),
#  ('nfts', 1),
#  ('workshop', 1),
#  ('big', 1),
#  ('free', 1),
#  ('daily', 1),
#  ('break', 1),
#  ('stories', 1),
#  ('roundup', 1),
#  ('trends', 1),
#  ('website', 1),
#  ('inbox', 1),
#  ('delivery', 1),
#  ('including', 1),
#  ('growth', 1),
#  ('indian', 1),
#  ('singapore', 1),
#  ('team', 1),
#  ('help', 1),
#  ('development', 1),
#  ('food', 1),
#  ('newsletter', 1),
#  ('financial', 1),
#  ('sea', 1),
#  ('fraud', 1),
#  ('female', 1),
#  ('like', 1),
#  ('founders', 1),
#  ('businesses', 1),
#  ('customers', 1),
#  ('people', 1),
#  ('just', 1),
#  ('data', 1),
#  ('weve', 1),
#  ('list', 1),
#  ('past', 1),
#  ('years', 1),
#  ('lists', 1),
#  ('generated', 1),
#  ('head', 1),
#  ('constantly', 1),
#  ('updated', 1),
#  ('autogenerated', 1),
#  ('invested', 1),
#  ('deals', 1),
#  ('money', 1),
#  ('theyve', 1),
#  ('herewhich', 1),
#  ('content', 1),
#  ('researchtechinasiacom', 1),
#  ('impact', 1)]

# %%
# If more than half of the author have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 5]
add_stop_words
# Out:
# ['funding',
#  'tech',
#  'raised',
#  'firm',
#  'new',
#  'startups',
#  'million',
#  'company',
#  'round',
#  'credit',
#  'startup',
#  'platform',
#  'asia',
#  'capital',
#  'investors',
#  'southeast',
#  'said',
#  'series',
#  'digital',
#  'billion']

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 

# Read in cleaned data
data_clean = pd.read_pickle('corpus.pkl')

# Add new stop words
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.content)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.index

# Pickle it for later use
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")
# Out:
# C:\Users\ASUS\miniconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Let's make some word clouds!

from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions

plt.rcParams['figure.figsize'] = [16, 6]

full_names = data_clean.author_name.values

# Create subplots for each author
for index, author in enumerate(data.columns):
    wc.generate(data_clean.content[author])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(full_names[index])
    
plt.show()

# %% [markdown]
# ### Findings:
# - 5 of 10 top authors are from India, which means we get articles about India a lot.
# - 2 from Singapore, 1 from Indonesia, 1 is a bot.
# - Daniel Rouquette is the one that not country-based articles except from bot.
# - From 11 SEA countries we only covering 3 countries.
# - Since TIA is covering SEA companies and startups, we need to get more articles from other SEA contries too.
